# %%
# importando bibliotecas

import pandas as pd
import statsmodels.api as sm

# %%
# advogados total

df_adv_total = pd.read_csv('DUMMY_TOTAL_ADV.csv', sep=';')
X = df_adv_total[['Dummy_ADV_CONTRA_0','Dummy_ADV_CONTRA_1']]
y = df_adv_total['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     3.806
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):             0.0511
# Time:                        10:41:25   Log-Likelihood:            -1.8246e+06
# No. Observations:              185005   AIC:                         3.649e+06
# Df Residuals:                  185003   BIC:                         3.649e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1536.8819      7.212    213.094      0.000    1522.746    1551.018
# ...

# %%
# advogados 2020

df_adv_total = pd.read_csv('DUMMY_2020_ADV.csv', sep=';')
X = df_adv_total[['Dummy_ADV_CONTRA_0','Dummy_ADV_CONTRA_1']]
y = df_adv_total['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     22.75
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           1.88e-06
# Time:                        10:41:25   Log-Likelihood:                -58956.
# No. Observations:                6852   AIC:                         1.179e+05
# Df Residuals:                    6850   BIC:                         1.179e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1326.1108     12.203    108.667      0.000    1302.188    1350.033
# ...

# %%
# advogados 2019

df_adv_total = pd.read_csv('DUMMY_2019_ADV.csv', sep=';')
X = df_adv_total[['Dummy_ADV_CONTRA_0','Dummy_ADV_CONTRA_1']]
y = df_adv_total['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.330
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):              0.249
# Time:                        10:41:26   Log-Likelihood:            -2.5521e+05
# No. Observations:               23710   AIC:                         5.104e+05
# Df Residuals:                   23708   BIC:                         5.104e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1413.1421     58.251     24.259      0.000    1298.966    1527.318
# ...

# %%
# advogados 2018

df_adv_total = pd.read_csv('DUMMY_2018_ADV.csv', sep=';')
X = df_adv_total[['Dummy_ADV_CONTRA_0','Dummy_ADV_CONTRA_1']]
y = df_adv_total['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     57.19
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           4.08e-14
# Time:                        10:41:26   Log-Likelihood:            -2.8805e+05
# No. Observations:               31009   AIC:                         5.761e+05
# Df Residuals:                   31007   BIC:                         5.761e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1392.5195     11.706    118.955      0.000    1369.575    1415.464
# ...

# %%
# advogados 2017

df_adv_total = pd.read_csv('DUMMY_2017_ADV.csv', sep=';')
X = df_adv_total[['Dummy_ADV_CONTRA_0','Dummy_ADV_CONTRA_1']]
y = df_adv_total['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     93.86
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           3.53e-22
# Time:                        10:41:27   Log-Likelihood:            -5.0881e+05
# No. Observations:               55692   AIC:                         1.018e+06
# Df Residuals:                   55690   BIC:                         1.018e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1529.2700      6.709    227.932      0.000    1516.120    1542.420
# ...

# %%
# advogados 2016

df_adv_total = pd.read_csv('DUMMY_2016_ADV.csv', sep=';')
X = df_adv_total[['Dummy_ADV_CONTRA_0','Dummy_ADV_CONTRA_1']]
y = df_adv_total['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     43.28
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           4.78e-11
# Time:                        10:41:27   Log-Likelihood:            -6.2234e+05
# No. Observations:               67742   AIC:                         1.245e+06
# Df Residuals:                   67740   BIC:                         1.245e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1676.6301      7.459    224.786      0.000    1662.011    1691.249
# ...

# %%
# UF total

df = pd.read_csv('DUMMY_TOTAL_UF.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     183.7
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:29   Log-Likelihood:            -1.8222e+06
# No. Observations:              185005   AIC:                         3.644e+06
# Df Residuals:                  184977   BIC:                         3.645e+06
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.295e+14   2.65e+14     -0.488      0.626    -6.5e+14    3.91e+14
# ...

# %%
# UF 2020

df = pd.read_csv('DUMMY_2020_UF.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.184
# Method:                 Least Squares   F-statistic:                     60.45
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          6.88e-283
# Time:                        10:41:29   Log-Likelihood:                -58257.
# No. Observations:                6852   AIC:                         1.166e+05
# Df Residuals:                    6825   BIC:                         1.168e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1998.4674     66.117     30.226      0.000    1868.858    2128.076
# ...

# %%
# UF 2019

df = pd.read_csv('DUMMY_2019_UF.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     3.847
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           1.35e-10
# Time:                        10:41:29   Log-Likelihood:            -2.5516e+05
# No. Observations:               23710   AIC:                         5.104e+05
# Df Residuals:                   23683   BIC:                         5.106e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2270.1812    293.533      7.734      0.000    1694.838    2845.525
# ...

# %%
# UF 2018

df = pd.read_csv('DUMMY_2018_UF.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     90.94
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:29   Log-Likelihood:            -2.8694e+05
# No. Observations:               31009   AIC:                         5.739e+05
# Df Residuals:                   30982   BIC:                         5.742e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2465.7804     52.400     47.057      0.000    2363.074    2568.487
# ...

# %%
# UF 2017

df = pd.read_csv('DUMMY_2017_UF.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     320.8
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:30   Log-Likelihood:            -5.0496e+05
# No. Observations:               55692   AIC:                         1.010e+06
# Df Residuals:                   55665   BIC:                         1.010e+06
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -3.183e+14    9.9e+14     -0.322      0.748   -2.26e+15    1.62e+15
# ...

# %%
# UF 2016

df = pd.read_csv('DUMMY_2016_UF.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.105
# Method:                 Least Squares   F-statistic:                     305.7
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:30   Log-Likelihood:            -6.1861e+05
# No. Observations:               67742   AIC:                         1.237e+06
# Df Residuals:                   67715   BIC:                         1.238e+06
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             4.236e+14   4.82e+14      0.879      0.380   -5.21e+14    1.37e+15
# ...

# %%
# motivo total

df = pd.read_csv('DUMMY_TOTAL_MOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     19.50
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          2.40e-288
# Time:                        10:41:32   Log-Likelihood:            -1.8238e+06
# No. Observations:              185005   AIC:                         3.648e+06
# Df Residuals:                  184919   BIC:                         3.649e+06
# Df Model:                          85
# Covariance Type:            nonrobust
# ...
#                                                                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# motivo 2020

df = pd.read_csv('DUMMY_2020_MOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     15.56
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           6.23e-77
# Time:                        10:41:32   Log-Likelihood:                -58741.
# No. Observations:                6852   AIC:                         1.175e+05
# Df Residuals:                    6821   BIC:                         1.178e+05
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                                                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# motivo 2019

df = pd.read_csv('DUMMY_2019_MOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                      -0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   -0.5550
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               1.00
# Time:                        10:41:33   Log-Likelihood:            -2.5521e+05
# No. Observations:               23710   AIC:                         5.105e+05
# Df Residuals:                   23679   BIC:                         5.107e+05
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                                                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# motivo 2018

df = pd.read_csv('DUMMY_2018_MOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     18.10
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          1.07e-112
# Time:                        10:41:33   Log-Likelihood:            -2.8776e+05
# No. Observations:               31009   AIC:                         5.756e+05
# Df Residuals:                   30972   BIC:                         5.759e+05
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                                                                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# motivo 2017

df = pd.read_csv('DUMMY_2017_MOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     29.83
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:34   Log-Likelihood:            -5.0770e+05
# No. Observations:               55692   AIC:                         1.016e+06
# Df Residuals:                   55612   BIC:                         1.016e+06
# Df Model:                          79
# Covariance Type:            nonrobust
# ...
#                                                                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# motivo 2016

df = pd.read_csv('DUMMY_2016_MOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     146.9
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:35   Log-Likelihood:            -6.2016e+05
# No. Observations:               67742   AIC:                         1.240e+06
# Df Residuals:                   67710   BIC:                         1.241e+06
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                                                                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# PRODUTO TOTAL

df = pd.read_csv('DUMMY_TOTAL_PRODUTO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     28.09
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          4.39e-219
# Time:                        10:41:36   Log-Likelihood:            -1.8240e+06
# No. Observations:              185005   AIC:                         3.648e+06
# Df Residuals:                  184962   BIC:                         3.649e+06
# Df Model:                          42
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
# PRODUTO 2020

df = pd.read_csv('DUMMY_2020_PRODUTO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     14.45
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           5.77e-64
# Time:                        10:41:36   Log-Likelihood:                -58777.
# No. Observations:                6852   AIC:                         1.176e+05
# Df Residuals:                    6824   BIC:                         1.178e+05
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
# PRODUTO 2019

df = pd.read_csv('DUMMY_2019_PRODUTO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                 1.860e+04
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:36   Log-Likelihood:            -2.1688e+05
# No. Observations:               23710   AIC:                         4.338e+05
# Df Residuals:                   23678   BIC:                         4.341e+05
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
# PRODUTO 2018

df = pd.read_csv('DUMMY_2018_PRODUTO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     28.72
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          1.86e-159
# Time:                        10:41:36   Log-Likelihood:            -2.8765e+05
# No. Observations:               31009   AIC:                         5.754e+05
# Df Residuals:                   30978   BIC:                         5.756e+05
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
# PRODUTO 2017

df = pd.read_csv('DUMMY_2017_PRODUTO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     70.99
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:37   Log-Likelihood:            -5.0760e+05
# No. Observations:               55692   AIC:                         1.015e+06
# Df Residuals:                   55655   BIC:                         1.016e+06
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
# PRODUTO 2016

df = pd.read_csv('DUMMY_2016_PRODUTO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     58.60
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:37   Log-Likelihood:            -6.2155e+05
# No. Observations:               67742   AIC:                         1.243e+06
# Df Residuals:                   67713   BIC:                         1.243e+06
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
# SUBMOTIVO TOTAL

df = pd.read_csv('DUMMY_TOTAL_SUBMOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     33.42
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:49   Log-Likelihood:            -1.8184e+06
# No. Observations:              185005   AIC:                         3.638e+06
# Df Residuals:                  184621   BIC:                         3.641e+06
# Df Model:                         383
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# SUBMOTIVO 2020

df = pd.read_csv('DUMMY_2020_SUBMOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     7.187
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          8.75e-107
# Time:                        10:41:50   Log-Likelihood:                -58545.
# No. Observations:                6852   AIC:                         1.173e+05
# Df Residuals:                    6728   BIC:                         1.182e+05
# Df Model:                         123
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# SUBMOTIVO 2019

df = pd.read_csv('DUMMY_2019_SUBMOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     3960.
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:52   Log-Likelihood:            -2.1672e+05
# No. Observations:               23710   AIC:                         4.337e+05
# Df Residuals:                   23562   BIC:                         4.349e+05
# Df Model:                         147
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# SUBMOTIVO 2018

df = pd.read_csv('DUMMY_2018_SUBMOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     5.780
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          4.14e-107
# Time:                        10:41:54   Log-Likelihood:            -2.8762e+05
# No. Observations:               31009   AIC:                         5.756e+05
# Df Residuals:                   30846   BIC:                         5.769e+05
# Df Model:                         162
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# SUBMOTIVO 2017

df = pd.read_csv('DUMMY_2017_SUBMOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     15.18
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:41:58   Log-Likelihood:            -5.0660e+05
# No. Observations:               55692   AIC:                         1.014e+06
# Df Residuals:                   55383   BIC:                         1.017e+06
# Df Model:                         308
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# SUBMOTIVO 2016

df = pd.read_csv('DUMMY_2016_SUBMOTIVO.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     117.1
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:42:03   Log-Likelihood:            -6.1772e+05
# No. Observations:               67742   AIC:                         1.236e+06
# Df Residuals:                   67656   BIC:                         1.236e+06
# Df Model:                          85
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# UNIDADE TOTAL

df = pd.read_csv('DUMMY_TOTAL_UNIDADE.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     60.97
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           1.47e-51
# Time:                        10:42:04   Log-Likelihood:            -1.8245e+06
# No. Observations:              185005   AIC:                         3.649e+06
# Df Residuals:                  185000   BIC:                         3.649e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -3.808e+13   3.47e+14     -0.110      0.913   -7.18e+14    6.42e+14
# ...

# %%
# UNIDADE 2020

df = pd.read_csv('DUMMY_2020_UNIDADE.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.749
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):              0.155
# Time:                        10:42:04   Log-Likelihood:                -58965.
# No. Observations:                6852   AIC:                         1.179e+05
# Df Residuals:                    6848   BIC:                         1.180e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1582.4880     21.710     72.893      0.000    1539.930    1625.046
# ...

# %%
# UNIDADE 2019

df = pd.read_csv('DUMMY_2019_UNIDADE.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9375
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):              0.421
# Time:                        10:42:04   Log-Likelihood:            -2.5520e+05
# No. Observations:               23710   AIC:                         5.104e+05
# Df Residuals:                   23706   BIC:                         5.104e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1754.9279     92.857     18.899      0.000    1572.922    1936.933
# ...

# %%
# UNIDADE 2018

df = pd.read_csv('DUMMY_2018_UNIDADE.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     102.9
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           2.82e-66
# Time:                        10:42:04   Log-Likelihood:            -2.8793e+05
# No. Observations:               31009   AIC:                         5.759e+05
# Df Residuals:                   31005   BIC:                         5.759e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1900.5149     15.804    120.257      0.000    1869.539    1931.491
# ...

# %%
# UNIDADE 2017

df = pd.read_csv('DUMMY_2017_UNIDADE.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     104.6
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           1.54e-67
# Time:                        10:42:04   Log-Likelihood:            -5.0870e+05
# No. Observations:               55692   AIC:                         1.017e+06
# Df Residuals:                   55688   BIC:                         1.017e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -1.898e+14   3.48e+15     -0.055      0.956      -7e+15    6.62e+15
# ...

# %%
# UNIDADE 2016

df = pd.read_csv('DUMMY_2016_UNIDADE.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     61.18
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           1.71e-39
# Time:                        10:42:04   Log-Likelihood:            -6.2227e+05
# No. Observations:               67742   AIC:                         1.245e+06
# Df Residuals:                   67738   BIC:                         1.245e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1.443e+15   2.97e+15      0.487      0.627   -4.37e+15    7.26e+15
# ...

# %%
# VARA TOTAL

df = pd.read_csv('DUMMY_TOTAL_VARA.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                 2.562e+04
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:42:22   Log-Likelihood:            -1.6922e+06
# No. Observations:              185005   AIC:                         3.384e+06
# Df Residuals:                  184981   BIC:                         3.385e+06
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
# VARA 2020

df = pd.read_csv('DUMMY_2020_VARA.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     63.72
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           2.82e-89
# Time:                        10:42:23   Log-Likelihood:                -58751.
# No. Observations:                6852   AIC:                         1.175e+05
# Df Residuals:                    6844   BIC:                         1.176e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
# VARA 2019

df = pd.read_csv('DUMMY_2019_VARA.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                 4.886e+04
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:42:25   Log-Likelihood:            -2.1670e+05
# No. Observations:               23710   AIC:                         4.334e+05
# Df Residuals:                   23697   BIC:                         4.335e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
# VARA 2018

df = pd.read_csv('DUMMY_2018_VARA.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     73.61
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          9.11e-179
# Time:                        10:42:26   Log-Likelihood:            -2.8764e+05
# No. Observations:               31009   AIC:                         5.753e+05
# Df Residuals:                   30996   BIC:                         5.754e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
# VARA 2017

df = pd.read_csv('DUMMY_2017_VARA.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     258.2
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:42:29   Log-Likelihood:            -5.0722e+05
# No. Observations:               55692   AIC:                         1.014e+06
# Df Residuals:                   55678   BIC:                         1.015e+06
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
# VARA 2016

df = pd.read_csv('DUMMY_2016_VARA.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     435.8
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:42:30   Log-Likelihood:            -6.1885e+05
# No. Observations:               67742   AIC:                         1.238e+06
# Df Residuals:                   67724   BIC:                         1.238e+06
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
# ADV_Total

df = pd.read_csv('base_adv.csv')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     25.33
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           3.60e-76
# Time:                        10:44:16   Log-Likelihood:            -1.8244e+06
# No. Observations:              185005   AIC:                         3.649e+06
# Df Residuals:                  184988   BIC:                         3.649e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2444.1163     40.659     60.112      0.000    2364.425    2523.808
# ...

# %%
# ADV_Total 2020

df = pd.read_csv('base_adv_2020.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     6.229
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           5.24e-14
# Time:                        10:42:31   Log-Likelihood:                -58918.
# No. Observations:                6852   AIC:                         1.179e+05
# Df Residuals:                    6835   BIC:                         1.180e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2032.8850     54.038     37.620      0.000    1926.954    2138.816
# ...

# %%
# ADV_Total 2019

df = pd.read_csv('base_adv_2019.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5577
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):              0.917
# Time:                        10:42:31   Log-Likelihood:            -2.5520e+05
# No. Observations:               23710   AIC:                         5.104e+05
# Df Residuals:                   23693   BIC:                         5.106e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2295.6781    250.801      9.153      0.000    1804.091    2787.265
# ...

# %%
# ADV_Total 2018

df = pd.read_csv('base_adv_2018.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     12.47
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           1.29e-33
# Time:                        10:42:32   Log-Likelihood:            -2.8798e+05
# No. Observations:               31009   AIC:                         5.760e+05
# Df Residuals:                   30992   BIC:                         5.761e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2218.5438     49.610     44.720      0.000    2121.306    2315.781
# ...

# %%
# ADV_Total 2017

df = pd.read_csv('base_adv_2017.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     59.31
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          4.70e-190
# Time:                        10:42:33   Log-Likelihood:            -5.0838e+05
# No. Observations:               55692   AIC:                         1.017e+06
# Df Residuals:                   55675   BIC:                         1.017e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2367.9294     32.381     73.126      0.000    2304.462    2431.397
# ...

# %%
# ADV_Total 2016

df = pd.read_csv('base_adv_2016.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     26.53
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           5.03e-80
# Time:                        10:42:34   Log-Likelihood:            -6.2215e+05
# No. Observations:               67742   AIC:                         1.244e+06
# Df Residuals:                   67725   BIC:                         1.244e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2557.0653     53.096     48.159      0.000    2452.997    2661.134
# ...

# %%
# municípios

df = pd.read_csv('base_cid.csv')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     65.32
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          1.09e-159
# Time:                        10:43:35   Log-Likelihood:            -1.8242e+06
# No. Observations:              185005   AIC:                         3.648e+06
# Df Residuals:                  184992   BIC:                         3.649e+06
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                         2951.7167     45.797     64.452      0.000    2861.955    3041.479
# ...

# %%
# municípios 2020

df = pd.read_csv('base_cid_2020.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     10.56
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           4.71e-21
# Time:                        10:43:53   Log-Likelihood:                -58905.
# No. Observations:                6852   AIC:                         1.178e+05
# Df Residuals:                    6839   BIC:                         1.179e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
# municípios 2019

df = pd.read_csv('base_cid_2019.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.651
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):             0.0709
# Time:                        10:43:58   Log-Likelihood:            -2.5520e+05
# No. Observations:               23710   AIC:                         5.104e+05
# Df Residuals:                   23697   BIC:                         5.105e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
# municípios 2018

df = pd.read_csv('base_cid_2018.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     15.95
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           2.56e-34
# Time:                        10:43:59   Log-Likelihood:            -2.8798e+05
# No. Observations:               31009   AIC:                         5.760e+05
# Df Residuals:                   30996   BIC:                         5.761e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
# municípios 2017

df = pd.read_csv('base_cid_2017.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     129.0
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          7.05e-320
# Time:                        10:44:00   Log-Likelihood:            -5.0809e+05
# No. Observations:               55692   AIC:                         1.016e+06
# Df Residuals:                   55679   BIC:                         1.016e+06
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
# municípios 2016

df = pd.read_csv('base_cid_2016.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     118.9
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):          4.28e-295
# Time:                        10:44:01   Log-Likelihood:            -6.2166e+05
# No. Observations:               67742   AIC:                         1.243e+06
# Df Residuals:                   67729   BIC:                         1.243e+06
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
# tratativa base total

df = pd.read_csv('BASE_ACORDO (1).csv', sep=';')

# %%
df.head()
# Out:
#                           ADV_CONTRA  ADV_CONTRA_DUMMY  Age  \
# 0               EDSON PAULO DA SILVA                 1  355
# 1  JULIO CESAR CORREIA DO NASCIMENTO                 1   21
# 2                NAO CONSTA ADVOGADO                 0   78
# 3                NAO CONSTA ADVOGADO                 0   90
# 4               FABRICIO YURI BORGES                 1   22
#
#       ANO_MES_PREVISTO COD_LOC  COD_MUN                MOTIVO  \
# 0  2019-05-01 00:00:00      GO  5200100    SUSPEITA DE FRAUDE
# 1  2017-06-01 00:00:00      GO  5200100     COBRANCA INDEVIDA
# 2  2016-09-01 00:00:00      GO  5200100     COBRANCA INDEVIDA
# 3  2016-09-01 00:00:00      GO  5200100       FALHA SISTEMICA
# 4  2017-09-01 00:00:00      GO  5200100  PROBLEMAS COM VENDAS
#
#                  PRODUTO                                          SUBMOTIVO  \
# 0  CLARO CARTAO/PRE-PAGO                     NAO RECONHECIMENTO DO CONTRATO
# ...

# %%
df_dummies = pd.get_dummies(data=df, columns=['ADV_CONTRA_DUMMY', 'COD_LOC', 'MOTIVO', 'PRODUTO', 'SUBMOTIVO', 'UNIDADE', 'VARA'])

# %%
from category_encoders import BinaryEncoder

# %%
df_binary = BinaryEncoder(cols=['ADV_CONTRA', 'COD_MUN']).fit_transform(df_dummies)

# %%
df_binary['VALOR_APAGAR']
# Out:
# 0            4500
# 1            2600
# 2            4000
# 3            3000
# 4         2458,58
#            ...
# 185000       3500
# 185001       3000
# 185002       3000
# 185003       2500
# 185004    2025,33
# Name: VALOR_APAGAR, Length: 185005, dtype: object

# %%
df_binary.to_csv('base_total.csv', index=False)

# %%
# total

df = pd.read_csv('base_geral.csv', sep = ';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
# C:\Users\Beatriz\anaconda3\lib\site-packages\statsmodels\base\model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\Beatriz\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\Beatriz\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\Beatriz\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     1290.
# ...

# %%
# total 2020

df = pd.read_csv('base_total_2020.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.328
# Method:                 Least Squares   F-statistic:                     16.44
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        11:23:35   Log-Likelihood:                -57493.
# No. Observations:                6852   AIC:                         1.154e+05
# Df Residuals:                    6634   BIC:                         1.169e+05
# Df Model:                         217
# Covariance Type:            nonrobust
# ...

# %%
# total 2019

df = pd.read_csv('base_total_2019.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     2564.
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        11:23:38   Log-Likelihood:            -2.1552e+05
# No. Observations:               23710   AIC:                         4.315e+05
# Df Residuals:                   23458   BIC:                         4.336e+05
# Df Model:                         251
# Covariance Type:            nonrobust
# ...

# %%
# total 2018

df = pd.read_csv('base_total_2018.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     17.09
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        11:23:43   Log-Likelihood:            -2.8591e+05
# No. Observations:               31009   AIC:                         5.724e+05
# Df Residuals:                   30738   BIC:                         5.746e+05
# Df Model:                         270
# Covariance Type:            nonrobust
# ...

# %%
# total 2017

df = pd.read_csv('base_total_2017.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     40.61
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        11:23:50   Log-Likelihood:            -5.0083e+05
# No. Observations:               55692   AIC:                         1.003e+06
# Df Residuals:                   55237   BIC:                         1.007e+06
# Df Model:                         454
# Covariance Type:            nonrobust
# ...

# %%
# total 2016

df = pd.read_csv('base_total_2016.csv', sep=';')
X = df.drop(['ANO_MES_PREVISTO', 'VALOR_APAGAR'], axis = 1)
y = df['VALOR_APAGAR']
X_train_sm = X
X_train_sm = sm.add_constant(X_train_sm)
lm_sm = sm.OLS(y,X_train_sm).fit()
print(lm_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           VALOR_APAGAR   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     146.1
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):               0.00
# Time:                        11:23:59   Log-Likelihood:            -6.1060e+05
# No. Observations:               67742   AIC:                         1.222e+06
# Df Residuals:                   67549   BIC:                         1.223e+06
# Df Model:                         192
# Covariance Type:            nonrobust
# ...

# %%
# estudo de correlação

import seaborn as sns
import matplotlib as plt
# %matplotlib inline
df = pd.read_csv('corr.csv', sep=';')
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-1c0545a396ad> in <module>
#       7 corrMatrix = df.corr()
#       8 sns.heatmap(corrMatrix, annot=True)
# ----> 9 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'
